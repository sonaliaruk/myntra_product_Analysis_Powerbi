# %% [markdown]
# <a href="https://colab.research.google.com/github/sonaliaruk/myntra_product_Analysis_Powerbi/blob/main/Myntra_datacleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROJECT -  Myntra Product Analysis🛍️
# BY - Sonali Aruk

# %% [markdown]
# ✨In this project, we explore product data from Myntra to uncover key insights about brands, categories, pricing, ratings, and gender preferences.
#
# - We began by performing data cleaning, where we handled missing values, corrected inconsistent data types, and ensured the dataset was well-structured and analysis-ready.
#
# - Following that, we conducted an in-depth Exploratory Data Analysis (EDA) to identify:
#
#  * The top-performing brands by product count and ratings
#
#  * Which categories are most stocked and preferred by each gender
#
#  * How ratings and reviews reflect customer satisfaction
#
#  * The distribution of prices across different product types
#
#  * Key trends based on gender-based preferences and individual categories
#
# This project helps understand how products are distributed across the Myntra platform and where businesses can focus efforts—whether it's improving underperforming brands, promoting high-rated ones, or aligning stock with customer interest

# %% [markdown]
# #📌 Phase 1: Data Cleaning

# %% [markdown]
# – We handled missing values by either imputing or removing them based on context.
#
# – Fixed inconsistent data types to enable proper calculations.
#
# – Removed duplicates , unnecessary columns and irrelevant entries to ensure accuracy.
#
# – Cleaned columns with extra characters or formatting issues for better readability.
#
# – Ensured categorical columns were properly labeled and standardized.
#
# ✍️ A detailed description of each data cleaning step and its purpose is provided below to ensure full transparency and understanding of the preprocessing process.
#
# ✅ After cleaning, the dataset was well-structured and ready for in-depth analysis.

# %% [markdown]
# #📌 Phase 2: Exploratory Data Analysis (EDA)

# %% [markdown]
#  * We used visualizations to examine top brands, most common categories, rating distributions, and customer behavior across genders.
#
# * 📊 We explored product availability by category and gender, average ratings by brand, and review trends to identify high-performing segments.
#
# * 📈 Various charts like bar plots, pie charts, histograms, and scatter plots helped uncover meaningful patterns and relationships in the data.
#
# * 🧠 These insights guided us toward understanding customer preferences and identifying potential areas for business improvement.

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# mount drive
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# Dataset Loading

# %%
# load dataset
df = pd.read_csv("/content/drive/MyDrive/Myntra Fasion Clothing.csv (1).zip")

# %%
df
# Out:
#                                                       URL  Product_id  \
# 0       https://www.myntra.com/jeans/roadster/roadster...     2296012
# 1       https://www.myntra.com/track-pants/locomotive/...    13780156
# 2       https://www.myntra.com/shirts/roadster/roadste...    11895958
# 3       https://www.myntra.com/shapewear/zivame/zivame...     4335679
# 4       https://www.myntra.com/tshirts/roadster/roadst...    11690882
# ...                                                   ...         ...
# 526559  https://www.myntra.com/sweaters/hm/hm-women-be...    16929990
# 526560  https://www.myntra.com/jackets/hm/hm-women-bla...    16026012
# 526561  https://www.myntra.com/dresses/250-designs/250...    17654114
# 526562  https://www.myntra.com/dresses/masaba/masaba-w...    12508700
# 526563  https://www.myntra.com/tshirts/jockey/jockey-w...    17856544
#
#           BrandName               Category Individual_category  \
# ...

# %% [markdown]
# Dataset First View

# %%
# display first 5 value
df.head()
# Out:
#                                                  URL  Product_id   BrandName  \
# 0  https://www.myntra.com/jeans/roadster/roadster...     2296012    Roadster
# 1  https://www.myntra.com/track-pants/locomotive/...    13780156  LOCOMOTIVE
# 2  https://www.myntra.com/shirts/roadster/roadste...    11895958    Roadster
# 3  https://www.myntra.com/shapewear/zivame/zivame...     4335679      Zivame
# 4  https://www.myntra.com/tshirts/roadster/roadst...    11690882    Roadster
#
#                 Category Individual_category category_by_Gender  \
# 0            Bottom Wear               jeans                Men
# 1            Bottom Wear         track-pants                Men
# 2                Topwear              shirts                Men
# 3  Lingerie & Sleep Wear           shapewear              Women
# 4                Western             tshirts              Women
#
#                                          Description  DiscountPrice (in Rs)  \
# ...

# %% [markdown]
# Dataset Information

# %%
# Displays a summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526564 entries, 0 to 526563
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   URL                    526564 non-null  object
#  1   Product_id             526564 non-null  int64
#  2   BrandName              526564 non-null  object
#  3   Category               526564 non-null  object
#  4   Individual_category    526564 non-null  object
#  5   category_by_Gender     526564 non-null  object
#  6   Description            526564 non-null  object
#  7   DiscountPrice (in Rs)  333406 non-null  float64
#  8   OriginalPrice (in Rs)  526564 non-null  float64
#  9   DiscountOffer          452258 non-null  object
#  10  SizeOption             526564 non-null  object
#  11  Ratings                190412 non-null  float64
#  12  Reviews                190412 non-null  float64
# dtypes: float64(4), int64(1), object(8)
# memory usage: 52.2+ MB

# %% [markdown]
# Dataset Rows & Columns

# %%
#display rows and columns
df.shape
# Out:
# (526564, 13)

# %% [markdown]
# Duplicate Values

# %%
# check duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# check duplicate values by product_id
df.duplicated('Product_id').sum()
# Out:
# np.int64(0)

# %% [markdown]
# Null Values

# %%
#check null values
null_value =  df.isnull().sum()
null_value
# Out:
# URL                           0
# Product_id                    0
# BrandName                     0
# Category                      0
# Individual_category           0
# category_by_Gender            0
# Description                   0
# DiscountPrice (in Rs)    193158
# OriginalPrice (in Rs)         0
# DiscountOffer             74306
# SizeOption                    0
# Ratings                  336152
# Reviews                  336152
# dtype: int64

# %%
# percentage of null values
df.isnull().sum() / len(df)*100
# Out:
# URL                       0.000000
# Product_id                0.000000
# BrandName                 0.000000
# Category                  0.000000
# Individual_category       0.000000
# category_by_Gender        0.000000
# Description               0.000000
# DiscountPrice (in Rs)    36.682720
# OriginalPrice (in Rs)     0.000000
# DiscountOffer            14.111485
# SizeOption                0.000000
# Ratings                  63.838774
# Reviews                  63.838774
# dtype: float64

# %%
#count of missing values
# filter column with missing values
null_value[null_value > 0].plot(kind = 'bar',figsize=(6,4))
plt.ylabel('columns')
plt.xlabel('count')
# Out:
# Text(0.5, 0, 'count')

# %%
## Using Seaborn to create HEATMAP to see missing values in Dataset
plt.figure(figsize=(8,5))
sns.heatmap(df.isnull(),yticklabels='False')
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# statistical view

# %%
#  statistical summary for object (categorical) type columns only for myntrafashion dataset
df.describe(include=['object'])
# Out:
#                                                       URL BrandName  \
# count                                              526564    526564
# unique                                             526564      2088
# top     https://www.myntra.com/tshirts/jockey/jockey-w...    Pothys
# freq                                                    1     16005
#
#            Category Individual_category category_by_Gender  \
# count        526564              526564             526564
# unique            8                  92                  2
# top     Indian Wear             tshirts              Women
# freq         145845               61198             339185
#
#                                               Description DiscountOffer  \
# count                                              526564        452258
# unique                                             429766          1418
# top     kanvin women pack of 2 printed pure cotton lou...       50% OFF
# ...

# %%
#  statistical summary for numerical type columns only for myntrafashion dataset
df.describe()
# Out:
#          Product_id  DiscountPrice (in Rs)  OriginalPrice (in Rs)  \
# count  5.265640e+05          333406.000000          526564.000000
# mean   1.506939e+07            1237.444401            2414.068615
# std    3.225710e+06            1052.063517            1916.962914
# min    2.739900e+04             127.000000              99.000000
# 25%    1.388053e+07             659.000000            1299.000000
# 50%    1.597106e+07             952.000000            1999.000000
# 75%    1.734741e+07            1469.000000            2899.000000
# max    1.846435e+07           27996.000000           90000.000000
#
#              Ratings        Reviews
# count  190412.000000  190412.000000
# mean        4.094892      61.990820
# std         0.494158     125.714537
# min         1.000000       0.000000
# 25%         3.900000       8.000000
# 50%         4.200000      18.000000
# 75%         4.400000      52.000000
# max         5.000000     999.000000

# %% [markdown]
# Unique Value

# %%
for i in df.columns.tolist():
  print(f"No. of unique value in {i} : {df[i].nunique()}")
# Out:
# No. of unique value in URL : 526564
# No. of unique value in Product_id : 526564
# No. of unique value in BrandName : 2088
# No. of unique value in Category : 8
# No. of unique value in Individual_category : 92
# No. of unique value in category_by_Gender : 2
# No. of unique value in Description : 429766
# No. of unique value in DiscountPrice (in Rs) : 4455
# No. of unique value in OriginalPrice (in Rs) : 4914
# No. of unique value in DiscountOffer : 1418
# No. of unique value in SizeOption : 3588
# No. of unique value in Ratings : 41
# No. of unique value in Reviews : 1000

# %% [markdown]
# # Data Wrangling

# %% [markdown]
# ---> Drop unncessary columns

# %%
# display all columns
df.columns
# Out:
# Index(['URL', 'Product_id', 'BrandName', 'Category', 'Individual_category',
#        'category_by_Gender', 'Description', 'DiscountPrice (in Rs)',
#        'OriginalPrice (in Rs)', 'DiscountOffer', 'SizeOption', 'Ratings',
#        'Reviews'],
#       dtype='object')

# %%
# drop column url
df.drop(['URL'],axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['Product_id', 'BrandName', 'Category', 'Individual_category',
#        'category_by_Gender', 'Description', 'DiscountPrice (in Rs)',
#        'OriginalPrice (in Rs)', 'DiscountOffer', 'SizeOption', 'Ratings',
#        'Reviews'],
#       dtype='object')

# %% [markdown]
# ---> Converting wrong data types to appropriate formats

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 526564 entries, 0 to 526563
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Product_id             526564 non-null  int64
#  1   BrandName              526564 non-null  object
#  2   Category               526564 non-null  object
#  3   Individual_category    526564 non-null  object
#  4   category_by_Gender     526564 non-null  object
#  5   Description            526564 non-null  object
#  6   DiscountPrice (in Rs)  333406 non-null  float64
#  7   OriginalPrice (in Rs)  526564 non-null  float64
#  8   DiscountOffer          452258 non-null  object
#  9   SizeOption             526564 non-null  object
#  10  Ratings                190412 non-null  float64
#  11  Reviews                190412 non-null  float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 48.2+ MB

# %%
# convert data type of discountoffer column
# First convert all values to string just in case some are numeric
df['DiscountOffer'] = df['DiscountOffer'].astype(str)

# Remove unwanted text
df['DiscountOffer'] = df['DiscountOffer'].str.replace('%', '', regex=False)
df['DiscountOffer'] = df['DiscountOffer'].str.replace('off', '', case=False, regex=True)
df['DiscountOffer'] = df['DiscountOffer'].str.replace(' ', '', regex=False)


# Convert cleaned strings to float
df['DiscountOffer'] = pd.to_numeric(df['DiscountOffer'], errors='coerce')

# %%
# convert data type of Reviews  column
# convert from float to int
df['Reviews'] = df['Reviews'].astype('Int64')

# %% [markdown]
# ---> Handling null or missing values

# %%
df.isnull().sum()
# Out:
# Product_id                    0
# BrandName                     0
# Category                      0
# Individual_category           0
# category_by_Gender            0
# Description                   0
# DiscountPrice (in Rs)    193158
# OriginalPrice (in Rs)         0
# DiscountOffer             97125
# SizeOption                    0
# Ratings                  336152
# Reviews                  336152
# dtype: int64

# %%
# fill rating column with 0  as no rating
df['Ratings'] = df['Ratings'].fillna(0)

# fill  review column with 0 as no review
df['Reviews'] = df['Reviews'].fillna(0)

# %%
# Fill missing DiscountOffer using DiscountPrice (in Rs) and OriginalPrice (in Rs)
mask_offer_missing = df['DiscountOffer'].isnull() & df['DiscountPrice (in Rs)'].notnull() # filter null from DiscountOffer and non null from DiscountPrice
df.loc[mask_offer_missing, 'DiscountOffer'] = (df.loc[mask_offer_missing, 'DiscountPrice (in Rs)'] / df.loc[mask_offer_missing, 'OriginalPrice (in Rs)'] * 100)


print(df['DiscountOffer'].isnull().sum()) #Missing values reduced from 97125 to 80933 after cleaning
# Out:
# 80933

# %%
# Fill missing DiscountPrice (in Rs) using DiscountOffer  and OriginalPrice (in Rs)
mask_offer_missing = df['DiscountPrice (in Rs)'].isnull() & df['DiscountOffer'].notnull() # filter null from DiscountPrice and non null from DiscountOffer
df.loc[mask_offer_missing, 'DiscountPrice (in Rs)'] = (df.loc[mask_offer_missing, 'OriginalPrice (in Rs)'] * df.loc[mask_offer_missing, 'DiscountOffer']/ 100)

df['DiscountPrice (in Rs)'].isnull().sum() #  Missing values reduced from 193158 to 80933 after cleaning
# Out:
# np.int64(80933)

# %%
df['DiscountPrice (in Rs)'] = df['DiscountPrice (in Rs)'].fillna(df['OriginalPrice (in Rs)'])
df['DiscountOffer'] = df['DiscountOffer'].fillna(0)

# %%
df['OriginalPrice (in Rs)'] = df['OriginalPrice (in Rs)'].astype(int)

df['DiscountPrice (in Rs)'] = df['DiscountPrice (in Rs)'].astype(int)

df['DiscountOffer'] = df['DiscountOffer'].astype(int)

# %%
df['DiscountPrice (in Rs)']
# Out:
# 0          824
# 1          517
# 2          629
# 3          893
# 4          209
#           ...
# 526559    9999
# 526560    9999
# 526561    9999
# 526562    9999
# 526563     799
# Name: DiscountPrice (in Rs), Length: 526564, dtype: int64

# %% [markdown]
# ---> Data Standardization

# %%
df['BrandName'].head(20)
# Out:
# 0                  Roadster
# 1                LOCOMOTIVE
# 2                  Roadster
# 3                    Zivame
# 4                  Roadster
# 5            Mast & Harbour
# 6                HIGHLANDER
# 7                     Mayra
# 8                  Roadster
# 9                  HERE&NOW
# 10    HRX by Hrithik Roshan
# 11                 Roadster
# 12                Anubhutee
# 13                   Athena
# 14                 Roadster
# 15               HIGHLANDER
# 16                  Vishudh
# 17                  Sangria
# 18            Tokyo Talkies
# 19               DressBerry
# Name: BrandName, dtype: object

# %%
# Capitalized the first letter of each value in the BrandName column for consistency
df['BrandName'] = df['BrandName'].str.title()
df['BrandName'].head(20)
# Out:
# 0                  Roadster
# 1                Locomotive
# 2                  Roadster
# 3                    Zivame
# 4                  Roadster
# 5            Mast & Harbour
# 6                Highlander
# 7                     Mayra
# 8                  Roadster
# 9                  Here&Now
# 10    Hrx By Hrithik Roshan
# 11                 Roadster
# 12                Anubhutee
# 13                   Athena
# 14                 Roadster
# 15               Highlander
# 16                  Vishudh
# 17                  Sangria
# 18            Tokyo Talkies
# 19               Dressberry
# Name: BrandName, dtype: object

# %% [markdown]
# ---> Handling Outliers

# %%
# check outlier using boxplot
sns.boxplot(data = df , y = 'OriginalPrice (in Rs)')
plt.figure(figsize = (10,6))
plt.show()

# %% [markdown]
# Most product prices are clustered within a small range, approximately between ₹500 and ₹3,000. However, there are numerous extreme outliers with significantly higher values.

# %%
sns.distplot(df['OriginalPrice (in Rs)'])
plt.figure(figsize = (10,6))
plt.show()

# %%
# Remove outliers using IQR
Q1 = df['OriginalPrice (in Rs)'].quantile(0.25)
Q3 = df['OriginalPrice (in Rs)'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df = df[(df['OriginalPrice (in Rs)'] >= lower) & (df['OriginalPrice (in Rs)'] <= upper)]

# %%
df.shape
# Out:
# (493319, 12)

# %%
sns.boxplot(data = df, y = 'OriginalPrice (in Rs)')
plt.figure(figsize = (7,3))
plt.show()

# %%
#check for discountprice column
sns.boxplot(data = df, y = 'DiscountPrice (in Rs)')
plt.figure(figsize = (7,3))
plt.show()

# %%
sns.distplot(df['DiscountPrice (in Rs)'])
plt.figure(figsize = (10,6))
plt.show()

# %%
# Remove outliers using IQR
Q1 = df['DiscountPrice (in Rs)'].quantile(0.25)
Q3 = df['DiscountPrice (in Rs)'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df = df[(df['DiscountPrice (in Rs)'] >= lower) & (df['DiscountPrice (in Rs)'] <= upper)]

# %%
sns.boxplot(data = df, y = 'DiscountPrice (in Rs)')
plt.figure(figsize = (7,3))
plt.show()

# %%
df.shape
# Out:
# (468039, 12)

# %%
#df.to_csv('cleaned_myntradata2.csv',index = False)

# %%
#from google.colab import files
#files.download('cleaned_myntradata2.csv')

# %% [markdown]
# # Manupulations I Performed on myntra dataset --

# %% [markdown]
# 1. **Dropped Unnecessary Column**
#
# * The `URL column`, which contained product page links, was dropped from the dataset.
#
# * **Reason** - Since it had no analytical value and wasn't required for modeling or visualization, it was considered unnecessary for the analysis.
#
# 2. **Converted Data Types for Consistency and Efficiency**
# * **Reason** - Several columns were converted to appropriate data types to ensure consistency and enable numerical analysis:
#
#  * `discountoffer`: Converted from string to integer after removing characters like % and off.
#
#  * `review`: Converted from float to integer for simplified representation.
#
#  * `originalprice (in Rs) and discountprice (in Rs)`: Converted from float to integer as prices are typically represented as whole numbers.
#
# 3. **Handled Missing Values Thoughtfully**
#
# * `rating and review` columns were filled with 0 for products with no ratings or reviews, indicating the absence of user feedback.
#
# * `Missing values in discountoffer` were calculated using the available originalprice and discountprice
# Similarly, missing `discountprice (in Rs)` values were calculated using
#
# 4. **Handled Outliers in Price Data**
#
# Outliers in the `originalprice (in Rs`) column were addressed using the Interquartile Range` (IQR) method`. This helped in removing extreme price values that could skew the analysis and model performance.
#
# **Final Dataset**:
#
# Dimensions : 12 columns and 477318 rows
#
# Cleaned and ready for further analysis

# %% [markdown]
# # Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables

# %%
# top 10 brands distribution using horizontal bar chart
plt.figure(figsize =(8,6))
top_brand = df['BrandName'].value_counts().head(20)
sns.barplot(y = top_brand.index,x = top_brand , palette = "viridis")
plt.title("Top 20 Brand Name Distribution")
plt.xlabel("Count")
plt.show()

# %% [markdown]
# Pothys have a higher number of products ,followed by Roadster,Kalini.

# %%
# top 10 brands distribution using horizontal bar chart
plt.figure(figsize =(8,6))
top_brand = df['BrandName'].value_counts().tail(20)
sns.barplot(y = top_brand.index,x = top_brand , palette = "viridis")
plt.title("least 20 Brand Name Distribution")
plt.xlabel("Count")
plt.show()

# %% [markdown]
# Zaveri Pearls, indusdiva loomnic,and several other brands have very few products — only one each.

# %%
# gender distribution using pie chart
plt.figure(figsize=(6,4))
gender = df['category_by_Gender'].value_counts()
plt.pie(gender.values,labels = gender.index,autopct='%1.1f%%', colors = ["#FF9898","#FFD586"])
plt.title("Gender Distribution")
plt.show()

# %% [markdown]
#  women customers are higher in number than men which means most products are targeted toward women. This suggests that the business focuses more on women's fashion, likely because of higher demand or interest from female customers.

# %%
# top 5 category type using horizonatl bar chart
plt.figure(figsize =(6,4))
top_category = df['Category'].value_counts()
sns.barplot(x = top_category.values ,y =top_category.index , palette = ["#113F67" ,"#065084","#34699A","#0F828C","#78B9B5"])
plt.title("Top 5 Category Distribution")
plt.xlabel("count")
plt.show()

# %% [markdown]
# The chart shows that most products are in the Western and Indian Wear categories. This means these are the most popular or focused categories. Bottom Wear and Lingerie & Sleep Wear have fewer products, so they may be less in demand or lower in priority

# %%
# Individual_category type using horizontal bar chart
plt.figure(figsize =(8,5))
top_category = df['Individual_category'].value_counts().head(30)
sns.barplot(y = top_category.values ,x =top_category.index , palette = ["#113F67" ,"#065084","#34699A","#0F828C","#78B9B5"])
plt.title("Top 30 Individual_category Distribution")
plt.xlabel("count")
plt.xticks(rotation = 90)
plt.show()

# %% [markdown]
# * T-shirts dominate the dataset by a large margin (over 60,000 items), showing they are the most commonly available or sold product.
#
# * Sarees and tops follow, indicating high interest or stock in women’s traditional and casual wear
#
# After the top 15 popular product types, the number of items in other categories drops quickly. This means many product types like nehru-jackets, lounge-shorts, jumpsuits, etc., are not very common and appear much less in the data.

# %%
plt.figure(figsize =(8,4))
sns.stripplot(
    data=df,
    y='Category',
    x='OriginalPrice (in Rs)',
    dodge=True,
    jitter=True,
    palette=['#0ABAB5'],
    size=3, alpha=0.6
)
plt.title('Price Distribution by Category')
plt.show()

# %% [markdown]
# While most product are priced within ₹200 to ₹3000, some items in categories like Indian Wear, western, and top wear have significantly higher prices.

# %%
top_categories = df['Individual_category'].value_counts().nlargest(10).index
filtered_df = df[df['Individual_category'].isin(top_categories)]

stack_data = filtered_df.groupby(['Individual_category', 'category_by_Gender']).size().unstack(fill_value=0)

# Plot
stack_data = stack_data.loc[top_categories]  # Ensure same order as top categories
stack_data.plot(kind='bar', stacked=True, figsize=(8, 4), color=['#205781','#4F959D'])

# Formatting
plt.title('Top 10 Individual_category by Gender Distribution')
plt.xlabel('Individual_category')
plt.ylabel('Number of Products')
plt.xticks(rotation=45)
plt.legend(title='Gender')
plt.tight_layout()
plt.show()

# %% [markdown]
# women's products are more that is available than men's in most top categories

# %%
# Step 1: Group by brand and get average rating
top_rated_brands = df.groupby('BrandName')['Ratings'].mean().sort_values(ascending=False).head(30)

# Step 2: Plot
plt.figure(figsize=(10, 5))
sns.barplot(y =top_rated_brands.values, x =top_rated_brands.index, palette='mako')

plt.title('Top 30 Brands by Average Rating')
plt.ylabel('Average Rating')
plt.xlabel('Brand Name')
plt.xticks(rotation = 90)
plt.tight_layout()
plt.show()

# %% [markdown]
# above brands are highest rating brands.Customers really like these brands and think they are of good quality. So, promoting these brands more in sales or advertisements can help attract more people and increase sales.
# Highlighting the high ratings in marketing  can attract more customers to these Brands.

# %%
filtered_brands = df.groupby('BrandName')['Ratings'].mean()
filtered_brands = filtered_brands[filtered_brands >= 1].sort_values(ascending=True).head(30)


plt.figure(figsize=(10, 5))
sns.barplot(y=filtered_brands.values, x=filtered_brands.index, palette='mako')

plt.title('Bottom 30 Brands with Rating ≥ 1')
plt.ylabel('Average Rating')
plt.xlabel('Brand Name')
plt.xticks(rotation = 90)
plt.tight_layout()
plt.show()

# %% [markdown]
#  These  brands have the lowest average ratings from customers.
# This means customers may not be  satisfied with their products or service.

# %%
# Step 1: Group by brand and get average rating
top_rated_brands = df.groupby('BrandName')['Reviews'].mean().sort_values(ascending=False).head(30)

# Step 2: Plot
plt.figure(figsize=(10, 5))
sns.barplot(y =top_rated_brands.values, x =top_rated_brands.index, palette='mako')

plt.title('Top 30 Brands by Average Reviews')
plt.ylabel('Average Reviews')
plt.xlabel('Brand Name')
plt.xticks(rotation = 90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Roadster Fast and furious , chemistry edition along with breil by fort collins have higher average reviews

# %%
filtered_brands = df.groupby('Category')['Ratings'].mean()
filtered_brands = filtered_brands[filtered_brands >= 0].sort_values(ascending=True)


plt.figure(figsize=(8, 5))
sns.barplot(x=filtered_brands.values, y=filtered_brands.index, palette='mako')

plt.title('category by average Rating ')
plt.xlabel('Average Rating')
plt.ylabel('category')
plt.tight_layout()
plt.show()

# %% [markdown]
# Plus Size category has the highest average rating (above 3), suggesting that customers are most satisfied with products in this category , even  Plus Size having fewer products than other categories but Western and Indian Wear dominate in product count still has lowest average rating, suggesting room for improvement.

# %%
# using histogram display Distribution of Ratings (Rating ≥ 1)
plt.figure(figsize = (7,4),facecolor="#FFF2E0")
filtered = df[df['Ratings'] >= 1]
ax = sns.histplot(data=filtered , x='Ratings', kde = True,bins = 30)
ax.set_facecolor('#FFF2E0')
plt.title('Distribution of Ratings (Rating ≥ 1)')
plt.xlabel('Ratings')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The distribution is highly left-skewed, meaning some ratings are near-perfect (close to 5), which is a positive sign for product quality.

# %%
# show distribution and oulier in rating using boxplot
plt.figure(figsize = (7,4))
filtered = df[df['Ratings'] >= 1]
ax = sns.boxplot(data=filtered , x='Ratings',color = 'Pink')
plt.title('Boxplot of Rtaings')
plt.xlabel('Ratings')
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# Most ratings fall between around 3.7 and 4.6, with a median close to 4.2, which is a positive sign for product quality.Their are some outlier between 1.0 to 3.4 . Which indictaes that very few products has less rating

# %%
#  rating vs review using scatterplot
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='Ratings', y='Reviews', color='teal', alpha=0.6)
plt.title('Scatter Plot of Ratings vs Reviews')
plt.xlabel('Ratings')
plt.ylabel('Number of Reviews')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# products with ratings between 3.5 and 4.7 tend to receive the highest number of reviews (some over 1000).
# Very low-rated apps (below 2.5) generally have fewer reviews, indicating lower user engagement or satisfaction.
# This shows that users are more likely to leave reviews for well-rated apps

# %%
#  originalprice vs discountoffer using scatterplot
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='OriginalPrice (in Rs)',y='DiscountOffer', color='teal', alpha=0.6)
plt.title('Scatter Plot of originalprice vs discountoffer')
plt.xlabel('originalprice')
plt.ylabel('discountoffer')
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# Discounts are widely distributed across all price ranges.
# Even low-priced items sometimes have high discount percentages.
# expensive items don't always get higher discounts.
#
# This means discount offers are not strictly dependent on price.

# %%
# using striplot showing Category vs Gender vs Ratings
plt.figure(figsize=(8, 6))
sns.stripplot(data=df, x='Category', y='Ratings', hue='category_by_Gender', jitter=True, dodge=True,alpha = 0.6,palette='mako')

plt.title('Category vs Gender vs Ratings')
plt.xticks(rotation=45)
plt.ylabel('Ratings')
plt.xlabel('Category')
plt.legend(title='Gender')
plt.tight_layout()
plt.show()

# %% [markdown]
#  Both men and women contribute ratings in most categories, but certain categories like Lingerie & Sleep Wear are rated only by women, while Topwear and Bottom Wear seem more male-dominated in reviews.
#
# This indicates gender-specific preferences and experiences, useful for tailoring product strategies and improving category-level engagement
#
# The Plus Size category generally receives higher ratings, mostly ranging between 3 to 5, indicating greater customer satisfaction compared to other categories
